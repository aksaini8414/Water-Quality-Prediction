# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df=pd.read_excel('Water quality.xlsx')
df.head()
# Out:
#    LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0  23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1  23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2  23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3  23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4  23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
#
#       F     Fe    K    Mg    Na  NO3    pH   SO4     Mn  AsIII
# 0  0.20  0.447  4.5  27.8  22.5  0.2  6.84  13.5  1.470      7
# 1  0.40  4.240  3.9  29.6  25.0  0.2  7.17   0.2  1.130    990
# 2  0.20  9.600  3.9  32.5  19.0  0.2  6.99   8.2  1.130     27
# 3  0.10  0.944  6.2  30.6  30.9  0.2  6.82   3.9  0.999      4
# 4  0.24  7.680  5.0  40.0  36.6  4.7  6.82   0.5  0.080      4

# %%
df.shape
# Out:
# (64, 17)

# %%
df.isnull().sum()
# Out:
# LAT_DEG       0
# LONG_DEG      0
# UNION         0
# WELL_DEPTH    0
# HCO3          0
# Ca            0
# Cl            0
# F             0
# Fe            0
# K             0
# Mg            0
# Na            0
# NO3           0
# pH            0
# SO4           0
# Mn            0
# AsIII         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LAT_DEG     64 non-null     float64
#  1   LONG_DEG    64 non-null     float64
#  2   UNION       64 non-null     object
#  3   WELL_DEPTH  64 non-null     float64
#  4   HCO3        64 non-null     int64
#  5   Ca          64 non-null     float64
#  6   Cl          64 non-null     float64
#  7   F           64 non-null     float64
#  8   Fe          64 non-null     float64
#  9   K           64 non-null     float64
#  10  Mg          64 non-null     float64
#  11  Na          64 non-null     float64
#  12  NO3         64 non-null     float64
#  13  pH          64 non-null     float64
#  14  SO4         64 non-null     float64
#  15  Mn          64 non-null     float64
#  16  AsIII       64 non-null     int64
# dtypes: float64(14), int64(2), object(1)
# memory usage: 8.6+ KB

# %%
df.describe()
# Out:
#          LAT_DEG   LONG_DEG  WELL_DEPTH        HCO3         Ca          Cl  \
# count  64.000000  64.000000   64.000000   64.000000   64.00000   64.000000
# mean   23.591833  89.815016   46.229688  541.812500  103.72500   24.675000
# std     0.046104   0.048968   43.011585  127.345658   35.51816   36.600963
# min    23.495800  89.697500   13.700000  200.000000   34.80000    1.800000
# 25%    23.563475  89.785750   24.400000  476.250000   78.27500    4.650000
# 50%    23.586250  89.816250   32.000000  554.500000  101.00000   10.450000
# 75%    23.616850  89.846575   49.775000  612.500000  123.25000   17.925000
# max    23.696400  89.902500  213.400000  848.000000  190.00000  195.000000
#
#                F         Fe          K         Mg          Na        NO3  \
# count  64.000000  64.000000  64.000000  64.000000   64.000000  64.000000
# mean    0.121875   5.642125   4.965625  32.680000   36.435937   0.453125
# ...

# %%
df.fillna(df.mean(), inplace=True)
df.isnull().sum()
# Out:
# C:\Users\bhans\AppData\Local\Temp\ipykernel_11232\1141678191.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(), inplace=True)
# LAT_DEG       0
# LONG_DEG      0
# UNION         0
# WELL_DEPTH    0
# HCO3          0
# Ca            0
# Cl            0
# F             0
# Fe            0
# K             0
# Mg            0
# Na            0
# NO3           0
# pH            0
# SO4           0
# Mn            0
# AsIII         0
# dtype: int64

# %%
df.hist(figsize=(14,14))
# Out:
# array([[<AxesSubplot:title={'center':'LAT_DEG'}>,
#         <AxesSubplot:title={'center':'LONG_DEG'}>,
#         <AxesSubplot:title={'center':'WELL_DEPTH'}>,
#         <AxesSubplot:title={'center':'HCO3'}>],
#        [<AxesSubplot:title={'center':'Ca'}>,
#         <AxesSubplot:title={'center':'Cl'}>,
#         <AxesSubplot:title={'center':'F'}>,
#         <AxesSubplot:title={'center':'Fe'}>],
#        [<AxesSubplot:title={'center':'K'}>,
#         <AxesSubplot:title={'center':'Mg'}>,
#         <AxesSubplot:title={'center':'Na'}>,
#         <AxesSubplot:title={'center':'NO3'}>],
#        [<AxesSubplot:title={'center':'pH'}>,
#         <AxesSubplot:title={'center':'SO4'}>,
#         <AxesSubplot:title={'center':'Mn'}>,
#         <AxesSubplot:title={'center':'AsIII'}>]], dtype=object)

# %%
plt.figure(figsize=(13,8))
sns.heatmap(df.corr(),annot=True,cmap='terrain')
plt.show()

# %%
df.boxplot(figsize=(14,7))
# Out:
# <AxesSubplot:>

# %%
how_many=df[(df['AsIII']>50)]
how_many
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 9   23.5094   89.8103             Kanaipur        25.9   607  123.0   3.6
# 11  23.4958   89.7861             Kanaipur        40.5   536   87.4  10.4
# 12  23.5158   89.8397              Kaijuri        53.3   614   57.1  56.7
# 15  23.5747   89.8825              Aliabad        40.5   566   95.7   7.6
# 22  23.6700   89.7253       Ishan Gopalpur        29.0   534   94.5   1.8
# 23  23.6603   89.7639       Ishan Gopalpur        28.0   580  125.0   3.0
# 34  23.5639   89.6975         Krishnanagar        28.0   668  117.0   8.2
# 38  23.5436   89.7678             Kanaipur        46.3   478   99.2   7.2
# 40  23.5414   89.8044              Kaijuri        87.8   556   99.4   3.8
# 41  23.5397   89.8381              Kaijuri        54.3   541   64.3  36.6
# 47  23.6406   89.8556         Decreer Char        26.8   617  134.0  11.3
# ...

# %%
how_many=df[(df['AsIII']>50)]
len(how_many)
# Out:
# 15

# %%
df.groupby(['UNION']).count()['HCO3'].to_frame()
# Out:
#                      HCO3
# UNION
# Aliabad                 7
# Ambikapur               3
# Char Madhabdia          4
# Decreer Char            4
# Faridpur Paurashava     8
# Greda                   3
# Ishan Gopalpur          4
# Kaijuri                13
# Kanaipur                5
# Krishnanagar            6
# Majchar                 5
# Uttar Channel           2

# %%
df.groupby(['UNION']).count()['HCO3'].plot()
# Out:
# <AxesSubplot:xlabel='UNION'>

# %%
df.groupby(['UNION']).count()['HCO3'].plot(kind='bar',figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='UNION'>

# %%
def example(c,w,s):#c=concentration,w=weight,s=standard value
    relative_weight=w/49
    waterqualityindex=relative_weight*(c/s)*100
    return waterqualityindex
x=example(df.HCO3,1,500)

# %%
df
# Out:
#     LAT_DEG  LONG_DEG                UNION  WELL_DEPTH  HCO3     Ca    Cl  \
# 0   23.6147   89.8553  Faridpur Paurashava        24.4   471  127.0  27.6
# 1   23.6075   89.8633  Faridpur Paurashava        27.4   580  142.0   9.3
# 2   23.6031   89.8272            Ambikapur        36.6   529  116.0  33.9
# 3   23.6064   89.8444  Faridpur Paurashava        18.9   568  116.0  16.5
# 4   23.5689   89.8536              Aliabad        45.7   561   88.4  13.5
# ..      ...       ...                  ...         ...   ...    ...   ...
# 59  23.5789   89.8411              Kaijuri        32.0   485   67.9  12.7
# 60  23.6339   89.7581              Majchar        16.8   485  103.0   4.8
# 61  23.5897   89.8128  Faridpur Paurashava        50.0   536   76.4   7.5
# 62  23.6033   89.8408  Faridpur Paurashava       185.0   668  106.0  78.2
# 63  23.5919   89.8417              Aliabad        50.0   432   54.6   4.8
#
#        F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  AsIII
# ...

# %%
df.drop(['LAT_DEG','LONG_DEG','UNION','WELL_DEPTH'],axis=1,inplace=True)

# %%
df
# Out:
#     HCO3     Ca    Cl     F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  \
# 0    471  127.0  27.6  0.20   0.447  4.5  27.8   22.5  0.2  6.84  13.5  1.470
# 1    580  142.0   9.3  0.40   4.240  3.9  29.6   25.0  0.2  7.17   0.2  1.130
# 2    529  116.0  33.9  0.20   9.600  3.9  32.5   19.0  0.2  6.99   8.2  1.130
# 3    568  116.0  16.5  0.10   0.944  6.2  30.6   30.9  0.2  6.82   3.9  0.999
# 4    561   88.4  13.5  0.24   7.680  5.0  40.0   36.6  4.7  6.82   0.5  0.080
# ..   ...    ...   ...   ...     ...  ...   ...    ...  ...   ...   ...    ...
# 59   485   67.9  12.7  0.14  18.400  4.2  44.0   18.6  0.2  6.38   0.5  0.246
# 60   485  103.0   4.8  0.08   0.879  3.2  29.8    9.7  0.2  6.83   0.1  0.822
# 61   536   76.4   7.5  0.20   8.270  4.8  36.3   39.0  0.2  6.85   0.1  0.078
# 62   668  106.0  78.2  0.15   3.530  4.6  41.1  108.0  0.2  6.88   0.1  0.581
# 63   432   54.6   4.8  0.16   6.270  6.1  31.0   32.2  0.2  6.88   0.1  0.136
#
#     AsIII
# 0       7
# ...

# %%
def example(c,w,s):#c=concentration,w=weight,s=standard value
    relative_weight=w/49
    waterqualityindex=relative_weight*(c/s)*100
    return waterqualityindex
x=example(df.HCO3,1,500)
df['sub_index_hco3']=x

# %%
df
# Out:
#     HCO3     Ca    Cl     F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  \
# 0    471  127.0  27.6  0.20   0.447  4.5  27.8   22.5  0.2  6.84  13.5  1.470
# 1    580  142.0   9.3  0.40   4.240  3.9  29.6   25.0  0.2  7.17   0.2  1.130
# 2    529  116.0  33.9  0.20   9.600  3.9  32.5   19.0  0.2  6.99   8.2  1.130
# 3    568  116.0  16.5  0.10   0.944  6.2  30.6   30.9  0.2  6.82   3.9  0.999
# 4    561   88.4  13.5  0.24   7.680  5.0  40.0   36.6  4.7  6.82   0.5  0.080
# ..   ...    ...   ...   ...     ...  ...   ...    ...  ...   ...   ...    ...
# 59   485   67.9  12.7  0.14  18.400  4.2  44.0   18.6  0.2  6.38   0.5  0.246
# 60   485  103.0   4.8  0.08   0.879  3.2  29.8    9.7  0.2  6.83   0.1  0.822
# 61   536   76.4   7.5  0.20   8.270  4.8  36.3   39.0  0.2  6.85   0.1  0.078
# 62   668  106.0  78.2  0.15   3.530  4.6  41.1  108.0  0.2  6.88   0.1  0.581
# 63   432   54.6   4.8  0.16   6.270  6.1  31.0   32.2  0.2  6.88   0.1  0.136
#
#     AsIII  sub_index_hco3
# ...

# %%
def example(c,w,s):#c=concentration,w=weight,s=standard value
    relative_weight=w/49
    waterqualityindex=relative_weight*(c/s)*100
    return waterqualityindex
x=example(df.Ca,4,75)
df['sub_index_Ca']=x

# %%
df#dataframe
# Out:
#     HCO3     Ca    Cl     F      Fe    K    Mg     Na  NO3    pH   SO4     Mn  \
# 0    471  127.0  27.6  0.20   0.447  4.5  27.8   22.5  0.2  6.84  13.5  1.470
# 1    580  142.0   9.3  0.40   4.240  3.9  29.6   25.0  0.2  7.17   0.2  1.130
# 2    529  116.0  33.9  0.20   9.600  3.9  32.5   19.0  0.2  6.99   8.2  1.130
# 3    568  116.0  16.5  0.10   0.944  6.2  30.6   30.9  0.2  6.82   3.9  0.999
# 4    561   88.4  13.5  0.24   7.680  5.0  40.0   36.6  4.7  6.82   0.5  0.080
# ..   ...    ...   ...   ...     ...  ...   ...    ...  ...   ...   ...    ...
# 59   485   67.9  12.7  0.14  18.400  4.2  44.0   18.6  0.2  6.38   0.5  0.246
# 60   485  103.0   4.8  0.08   0.879  3.2  29.8    9.7  0.2  6.83   0.1  0.822
# 61   536   76.4   7.5  0.20   8.270  4.8  36.3   39.0  0.2  6.85   0.1  0.078
# 62   668  106.0  78.2  0.15   3.530  4.6  41.1  108.0  0.2  6.88   0.1  0.581
# 63   432   54.6   4.8  0.16   6.270  6.1  31.0   32.2  0.2  6.88   0.1  0.136
#
# ...

# %%
z=df.iloc[:,13:]
z
# Out:
#     sub_index_hco3  sub_index_Ca
# 0         1.922449     13.823129
# 1         2.367347     15.455782
# 2         2.159184     12.625850
# 3         2.318367     12.625850
# 4         2.289796      9.621769
# ..             ...           ...
# 59        1.979592      7.390476
# 60        1.979592     11.210884
# 61        2.187755      8.315646
# 62        2.726531     11.537415
# 63        1.763265      5.942857
#
# [64 rows x 2 columns]

# %%
z=df.iloc[:,13:]
z
c=z.sum(axis=1)

# %%
c
# Out:
# 0     15.745578
# 1     17.823129
# 2     14.785034
# 3     14.944218
# 4     11.911565
#         ...
# 59     9.370068
# 60    13.190476
# 61    10.503401
# 62    14.263946
# 63     7.706122
# Length: 64, dtype: float64

# %%
z['final index']=c
z
# Out:
#     sub_index_hco3  sub_index_Ca  final index
# 0         1.922449     13.823129    15.745578
# 1         2.367347     15.455782    17.823129
# 2         2.159184     12.625850    14.785034
# 3         2.318367     12.625850    14.944218
# 4         2.289796      9.621769    11.911565
# ..             ...           ...          ...
# 59        1.979592      7.390476     9.370068
# 60        1.979592     11.210884    13.190476
# 61        2.187755      8.315646    10.503401
# 62        2.726531     11.537415    14.263946
# 63        1.763265      5.942857     7.706122
#
# [64 rows x 3 columns]

# %%
z['final index']=c
z.to_excel('PREETY2.xlsx')
